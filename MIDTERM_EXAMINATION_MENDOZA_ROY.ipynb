# %% [markdown]
# <a href="https://colab.research.google.com/github/MendozaRoycpe/CPE009A_Mendoza-Roy/blob/main/MIDTERM_EXAMINATION_MENDOZA_ROY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title: " MIDTERM EXAMINATION - QUESTION#23"</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed: March 12, 2026 ** |
# | **Section**: CPE12S2 | **Date Submitted: March 12, 2026 ** |
# | **Student Name**: Mendoza, Roy Gabriel I. | **Instructor's Name: Engr. Sayo** |
# </center>

# %% [markdown]
# **Instructions **
#
# Instruction: Insert the link of your program(Colab/Github) here.
#
# Write a program that uses nested loops to print this pattern:
#
# *# 1
#
# **# 2
#
# ***# 3
#
# ****# 4
#
# *****# 5
#
# ****# 4
#
# ***# 3
#
# **# 2
#
# *# 1

# %%
#list of the variable and its content
scores = (5,6,7)
colors = ("red", "green", "orange")
fruits = ("banana", "melon", "strawberry")
dish = ("ice cream", "cake", "pudding")

# Code
for x in scores: # 1
  for y in colors: #2
    for z in fruits: #3
      for v in dish: #4
        if v == "pudding": #5
          continue
      if z == "melon": #4
        continue
    if y == "green": #3
      continue
  if x == 7: #2
    break

    #Printing of output
print(x,y,z,v) #1
# Out:
# 7 orange strawberry pudding
