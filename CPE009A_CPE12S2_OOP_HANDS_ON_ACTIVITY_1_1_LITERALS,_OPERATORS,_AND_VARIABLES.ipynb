# %% [markdown]
# <a href="https://colab.research.google.com/github/MendozaRoycpe/CPE009A_Mendoza-Roy/blob/main/CPE009A_CPE12S2_OOP_HANDS_ON_ACTIVITY_1_1_LITERALS%2C_OPERATORS%2C_AND_VARIABLES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STUDENT NAME: MENDOZA, ROY GABRIEL I.
# # SECTION: CPE12S2
# # PROGRAM: COMPUTER ENGINEER

# %%
# Step 1 of Assigning variables of different data types in Python

value = 5
print(value)
# Out:
# 5

# %%
# Step 2 of Assigning variables of different data types in Python

type(value)
# Out:
# int

# %%
# Step 3 of Assigning variables of different data types in Python

value = 5.0
print(value)
# Out:
# 5.0

# %%
# Step 4 of Assigning variables of different data types in Python

type(value)
# Out:
# float

# %%
# Step 5 of Assigning variables of different data types in Python
#letter a

value = 2+3j
print(value)
type(value)
# Out:
# (2+3j)
# complex

# %%
# Letter B

value = 'Hello World'
print(value)
type(value)
# Out:
# Hello World
# str

# %%
#Letter C

value = "Hello World"
print(value)
type(value)
# Out:
# Hello World
# str

# %%
#Letter D

value = True
print(value)
type(value)
# Out:
# True
# bool

# %%
#Letter E

value = False
print(value)
type(value)
# Out:
# False
# bool

# %%
#Letter F

value = [1,2,3,4,5]
print(value)
type(value)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
#Letter G

value = (1,2,3,4,5)
print(value)
type(value)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %%
#Letter H

value = {'name': 'Roy_Gabriel'}
print(value)
type(value)
# Out:
# {'name': 'Roy_Gabriel'}
# dict

# %%
#Letter I

value = None
print(value)
type(value)
# Out:
# None
# NoneType

# %%
#Step 6 of Assigning variables of different data types in Python

value=5

#Step 7 of Assigning variables of different data types in Python
value2=-6

#Trial
print(value)
print(value2)
# Out:
# 5
# -6

# %%
#Step 1 in Performing Operations with Python

print(value + value2)
# Out:
# -1

# %%
#Step A in Performing Operations with Python

value, value2 = 5.0, 6
print(value + value2)
# Out:
# 11.0

# %%
#Step B in Performing Operations with Python

value, value2 = -5,6.1
print(value + value2)
# Out:
# 1.0999999999999996

# %%
#Step C in Performing Operations with Python

value,value2="Hello",' world'
print(value + value2)
# Out:
# Hello world

# %%
#Step D in Performing Operations with Python

value, value2 = [1,2,3],[4,5,6]
print(value + value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Step E in Performing Operations with Python

value,value2= (1,2,3),(4,5,6)
print(value + value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#Step F in Performing Operations with Python

value,value2= {"name": "Roy_Gabriel"}, {"age":2}
print(value, value2) #could not print out the variables at the same time because of the difference of data type
# Out:
# {'name': 'Roy_Gabriel'} {'age': 2}

# %%
#Step 3 in Performing Operations with Python
value, value2=30,4
#a
print(value* value2)
#b
print(value2**2)
#c
print(value2**3)
#d
print(value*value2**2+1)
#e
print(value/value2)
#f
print(value%value2)
# Out:
# 120
# 16
# 64
# 481
# 7.5
# 2

# %%
#Step 1-3 in Receiving Input Data using Python
name=input("Enter your Name:")
weight=input("Enter your Weight(kg):")
height=input("Enter your Height(meters):")

#Step 4-6 in Receiving Input Data using Python
bmi=float(weight)/(float(height)*float(height))
print("\nName:", name,"\nWeight:", weight, "\nHeight:", height,"\nBMI:",bmi)
# Out:
# Enter your Name:Mendoza
# Enter your Weight(kg):60
# Enter your Height(meters):1.64
#
# Name: Mendoza
# Weight: 60
# Height: 1.64
# BMI: 22.308149910767405

# %%
#Supplementary Activity

#1. Write the Python equivalent code of the following C code:
base=float(input("Enter the base of the triangle:"))
height=float(input("Enter the height of the triangle:"))
area=float((1/2)*base*height)
print(area)
# Out:
# Enter the base of the triangle:6.3
# Enter the height of the triangle:5.756536216563
# 18.13308908217345

# %%
#2. Write a program that would convert Celsius to Fahrenheit given the
#formula: F = (C × 9/5) + 32
c=float(input("Enter the temperature in Celsius:"))
f=float((c*9/5)+32)
print(f)
# Out:
# Enter the temperature in Celsius:-20
# -4.0

# %%
#3. Write a program that can determine the distance between two points given the coordinate

x1=int(input("Enter the first x coordinate:"))
y1=int(input("Enter the first y coordinate:"))
x2=int(input("Enter the second x coordinate:"))
y2=int(input("Enter the second y coordinate:"))
distance=((x2-x1)**2+(y2-y1)**2)**0.5
print("The distance between the two points is:",distance)
# Out:
# Enter the first x coordinate:2
# Enter the first y coordinate:2
# Enter the second x coordinate:-3
# Enter the second y coordinate:3
# The distance between the two points is: 5.0990195135927845
