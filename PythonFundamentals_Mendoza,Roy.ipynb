# %% [markdown]
# <a href="https://colab.research.google.com/github/MendozaRoycpe/CPE009A_Mendoza-Roy/blob/main/PythonFundamentals_Mendoza%2CRoy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PYTHON INDENTATION

# %%
if 5>2:
  print("five is greater than two")
# Out:
# five is greater than two

# %% [markdown]
# Python Comment

# %%
#This is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Python Variable

# %%
x=1
a, b=0,-1
a,b,c=0,-1,2

b="Sally"#this is a type of string

print(b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b="sally"#This is a type of string
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type()function

# %%
#Example
x=5
y="John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "Double Quotes" or 'Single' Quotes
# #string variable can be declared either by using single or double quotes:

# %%
#Example:
y="John"
y='John'

# %% [markdown]
# Case Sensitive

# %%
#Example

a=4
A="Sally"
#A will not overwrite a

# %% [markdown]
# Multiple Variables

# %%
#Example:

x,y,z="one","two","three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One value to multiple variables

# %%
#Example:

x=y=z="four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
#The python print is used to output variables and = is used to combine both text and variable
#Example

x="enjoying"
print("Python Programming is "+x)

#Other way:

x="Python is "
y="enjoying"
z=x+y
print(z)
# Out:
# Python Programming is enjoying
# Python is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
10//3

#Examples;
x=5
y=3
#This is addition(plus ofc)
print(x+y)
#This is substraction
print(x-y)
#this is multiplication
print(x*y)
#this is division
print(x/y)
#this is modulus
print(x%y)
#this is flood division(getting the whole no. from the module)
print(x//y)
#this is the exponential
print(x**y)

#Other way of typing
sum=x+y
sum
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 1
# 125
# 8

# %% [markdown]
# Assignment Operators

# %%
s=1
s+=3
print(s)
s-=3
print(s)
s*=3
print(s)
s/=3
print(s)
s%=3
print(s)
s//=3
print(s)
s**=3
print(s)
s=1
print(s)
s|=3
print(s)
s=1
print(s)
s^=3
print(s)
s=1
print(s)
s>>=3
print(s)
s=1
print(s)
s<<=3
print(s)
s=1
s&=3
print(s)




print(s)
# Out:
# 4
# 1
# 3
# 1.0
# 1.0
# 0.0
# 0.0
# 1
# 3
# 1
# 2
# 1
# 0
# 1
# 8
# 1
# 1
